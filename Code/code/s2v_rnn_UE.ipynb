# %%
import numpy as np
import pandas as pd
import cPickle
from collections import defaultdict
import re

import gensim

from sklearn.cross_validation import StratifiedShuffleSplit
from sklearn.metrics import roc_auc_score
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

import keras
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten, Reshape
from keras.layers.embeddings import Embedding
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.optimizers import Adadelta
from keras.constraints import unitnorm
from keras.regularizers import l2
from keras.utils import np_utils
from keras import callbacks
from keras.layers import LSTM, SimpleRNN, GRU
# Out:
# //anaconda/lib/python2.7/site-packages/pandas/computation/__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)
# Using Theano backend.

# %% [markdown]
# # LOAD DATA

# %%
df0_train_s = pd.read_pickle('../data/df0_train_s_ue0.pkl')
df0_test_s = pd.read_pickle('../data/df0_test_s_ue0.pkl')

# %%
select_cols = [u'pos_num', u'neg_num', u'pos', u'ef0', u'ef1', u'ef2', u'ef3', u'ef4', u'ef5', u'ef6', u'ef7', u'ef8', u'ef9']

# %%
train_x = np.c_[df0_train_s[select_cols].values, np.array((df0_train_s['sen_vec']).tolist())]
train_y = np.array(df0_train_s['polarity'])

test_x =  np.c_[df0_test_s[select_cols].values, np.array((df0_test_s['sen_vec']).tolist())]
test_y = np.array(df0_test_s['polarity'])

print 'train_x shape:',train_x.shape
print 'train_y shape:',train_y.shape

print 'test_x shape:',test_x.shape
print 'test_y shape:',test_y.shape
# Out:
# train_x shape: (5000, 513)
# train_y shape: (5000,)
# test_x shape: (5000, 513)
# test_y shape: (5000,)

# %% [markdown]
# # MODEL TRAINING

# %% [markdown]
# ## SOME PREPARATION

# %%
# %matplotlib inline

import matplotlib.pyplot as plt 

def plot_history(history):
    # summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
def get_test_acc(test_x_cat,test_y,model):
    p1 = model.predict_proba(test_x_cat)
    return np.mean(test_y==(np.argmax(p1,axis=1)))
    

train_x_cat = train_x.reshape(train_x.shape[0],1,train_x.shape[1])
test_x_cat = test_x.reshape(test_x_cat.shape[0],1,test_x_cat.shape[1])
train_y_cat = np_utils.to_categorical(train_y)
test_y_cat = np_utils.to_categorical(test_y)

# %% [markdown]
# ## RNN1
#
# lr = 0.01
#
# nesterov = False
#
# epoch = 1000
#
# batch_size = 32

# %%
from keras.optimizers import SGD

sgd = SGD()

model_rnn = Sequential()
model_rnn.add(SimpleRNN(64, input_shape=[1,train_x.shape[1]]))  # try using a GRU instead, for fun
model_rnn.add(Dense(10))
model_rnn.add(Activation('relu'))
model_rnn.add(Dropout(0.5))
model_rnn.add(Dense(2))
model_rnn.add(Activation('softmax'))

model_rnn.compile(loss="categorical_crossentropy", optimizer=sgd,metrics=['accuracy'])

# %%
model_rnn.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# simplernn_1 (SimpleRNN)          (None, 64)            36992       simplernn_input_1[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 10)            650         simplernn_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 10)            0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 10)            0           activation_1[0][0]
# ____________________________________________________________________________________________________
# ...

# %%
history = model_rnn.fit(train_x_cat,train_y_cat,nb_epoch=500,validation_split=0.2)  #,verbose=0
# Out:
# Train on 4000 samples, validate on 1000 samples
# Epoch 1/500
# 4000/4000 [==============================] - 0s - loss: 0.6771 - acc: 0.5823 - val_loss: 0.6591 - val_acc: 0.6380
# Epoch 2/500
# 4000/4000 [==============================] - 0s - loss: 0.6635 - acc: 0.6232 - val_loss: 0.6520 - val_acc: 0.6470
# Epoch 3/500
# 4000/4000 [==============================] - 0s - loss: 0.6554 - acc: 0.6272 - val_loss: 0.6300 - val_acc: 0.6560
# Epoch 4/500
# 4000/4000 [==============================] - 0s - loss: 0.6440 - acc: 0.6405 - val_loss: 0.6214 - val_acc: 0.6670
# Epoch 5/500
# 4000/4000 [==============================] - 0s - loss: 0.6367 - acc: 0.6392 - val_loss: 0.6122 - val_acc: 0.6730
# Epoch 6/500
# 4000/4000 [==============================] - 0s - loss: 0.6304 - acc: 0.6535 - val_loss: 0.6098 - val_acc: 0.6770
# Epoch 7/500
# 4000/4000 [==============================] - 0s - loss: 0.6257 - acc: 0.6580 - val_loss: 0.6066 - val_acc: 0.6760
# Epoch 8/500
# ...

# %%
plot_history(history)

# %%
get_test_acc(test_x_cat,test_y,model_rnn)
# Out:
# 4736/5000 [===========================>..] - ETA: 0s
# 0.72919999999999996

# %% [markdown]
# ## RNN2
#
# lr = 0.01
#
# nesterov = True
#
# epoch = 1000
#
# batch_size = 32

# %%
from keras.optimizers import SGD

sgd = SGD(lr=0.01,nesterov=True)

model_rnn2 = Sequential()
model_rnn2.add(SimpleRNN(64, input_shape=[1,train_x.shape[1]]))  # try using a GRU instead, for fun
model_rnn2.add(Dense(10))
model_rnn2.add(Activation('relu'))
model_rnn2.add(Dropout(0.5))
model_rnn2.add(Dense(2))
model_rnn2.add(Activation('softmax'))

model_rnn2.compile(loss="categorical_crossentropy", optimizer=sgd,metrics=['accuracy'])

# %%
history2 = model_rnn2.fit(train_x_cat,train_y_cat,nb_epoch=500,validation_split=0.2,verbose=0)

# %%
plot_history(history2)

# %%
get_test_acc(test_x_cat,test_y,model_rnn2)
# Out:
# 4096/5000 [=======================>......] - ETA: 0s
# 0.73440000000000005
